# %% [markdown]
# # HW 16 - Animation
# ULAB - Physics and Astronomy Division \
# Due **Sunday, March 16th, 2025 at 11:59pm** on Gradescope
#
# **Make sure to work on this notebook in DataHub!**
#
# # 1) Recap of lecture
# **Copy and paste** your code from lecture for the neural network with the **default** settings (i.e. before we improved the model). Make sure to also import the `data.py` file.

# %%
# Install
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl (151.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.0/151.0 MB 1.8 MB/s eta 0:00:0000:0100:02
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cpu/torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 2.2 MB/s eta 0:00:0000:0100:01
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cpu/torchaudio-2.2.2-cp312-cp312-macosx_10_13_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 2.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.12/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# Installing collected packages: torch, torchvision, torchaudio
# Successfully installed torch-2.2.2 torchaudio-2.2.2 torchvision-0.17.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import data
import matplotlib.pyplot as plt
import torch

# Code
# model = torch.nn.Sequential(
    # torch.nn.Linear(2, 50), # Input layer to Hidden layer
    # torch.nn.Sigmoid(), # Activation function
    # torch.nn.Linear(50, 1) # Hidden layer to Output layer
    # )

# loss_fn = torch.nn.MSELoss()
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# for t in range(1100): # 1000th Iteration
    # y_pred = model(data.x)
    # loss = loss_fn(y_pred, data.y)
    # optimizer.zero_grad()
    # loss.backward()
    # optimizer.step()

    # if t % 100 == 0:
        # print(f"Iteration {t}, Loss: {loss.item()}")

# %% [markdown]
# What is the difference between artificial intelligence, machine learning and deep learning?

# %%
# AI is an umbrella term, used to describe computers that perform tasks like human 
# intelligence (including recognize patterns, make decisions, and learn from experience.

# Machine Learning (ML) is a subset of AI, where computers learn from data rather than
# being programmed explicitly.

# Deep Learning (DL) is a subset of ML, which uses neural networks that have multiple 
# layers to process the data. It is good at understanding complex patterns, and can
# map inputs to outputs with neurons.

# %% [markdown]
# What is a neural network?

# %%
# A neural network is a model inspired by how the human brain works in order to 
# learn/understand patterns. It has 3 layers: the input, hidden, and output layers.

# %% [markdown]
# In lecture, we used `torch.nn.Linear(2, 50)`. What do the numbers `2` and `50` represent?

# %%
# In torch.nn.Linear(2, 50), the number 2 represents the input layer and 50 
# represents the hidden layer.

# %% [markdown]
# What does the activation function do?

# %%
# An activation funtion looks like torch.nn.Sigmoid() and it introduces 
# non-linearity into the model. It helps the neurons work in a smoother and 
# more continuous way.

# %% [markdown]
# What is a loss function? Why do we need one?

# %%
# A loss fucntion looks like loss_fn = torch.nn.MSELoss() and it tells us how wrong 
# our model is. It is important to have one so that the model can learn how off it is and 
# optimize the loss with an optimizer.

# %% [markdown]
# Why do we call `optimizer.zero_grad()` before calling `loss.backward()`?

# %%
# We call optimizer.zero_grad() to reset gradients and then call loss.backward() to 
# re-compute gradients. This way, each iteration runs smoothly.

# %% [markdown]
# # 2) Modifying the Neural Network
# What line do you need to modify to use **30 neurons** instead of **50**? Don't change anything else. Give the original and then modified line.

# %%
# 50 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), # Input layer to Hidden layer
    torch.nn.Sigmoid(), # Activation function
    torch.nn.Linear(50, 1) # Hidden layer to Output layer
    )
# 30 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 30), # Input layer to Hidden layer
    torch.nn.Sigmoid(), # Activation function
    torch.nn.Linear(30, 1) # Hidden layer to Output layer
    )

# %% [markdown]
# With your default code above, run your model with **30 neurons**. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# 30 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 30), # Input layer to Hidden layer
    torch.nn.Sigmoid(), # Activation function
    torch.nn.Linear(30, 1) # Hidden layer to Output layer
    )

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 1.0358538627624512
# Iteration 100, Loss: 0.9884501099586487
# Iteration 200, Loss: 0.940515398979187
# Iteration 300, Loss: 0.8379248380661011
# Iteration 400, Loss: 0.7018325328826904
# Iteration 500, Loss: 0.5809168219566345
# Iteration 600, Loss: 0.4893612861633301
# Iteration 700, Loss: 0.41624876856803894
# Iteration 800, Loss: 0.35446760058403015
# Iteration 900, Loss: 0.30430591106414795
# Iteration 1000, Loss: 0.2636105418205261

# %%
# Loss from Lecture
Loss_from_lecture = 0.112526535987854

# Difference
0.2636105418205261 - Loss_from_lecture
# Out:
# 0.15108400583267212

# %% [markdown]
# Return to **50 neurons**. Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.ReLU`. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# 50 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), # Input layer to Hidden layer
    torch.nn.ReLU(), # Activation function
    torch.nn.Linear(50, 1) # Hidden layer to Output layer
    )

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 1.390430212020874
# Iteration 100, Loss: 0.864672839641571
# Iteration 200, Loss: 0.731057345867157
# Iteration 300, Loss: 0.6102237701416016
# Iteration 400, Loss: 0.5268774032592773
# Iteration 500, Loss: 0.46563661098480225
# Iteration 600, Loss: 0.40395504236221313
# Iteration 700, Loss: 0.35792189836502075
# Iteration 800, Loss: 0.3244064152240753
# Iteration 900, Loss: 0.3043177127838135
# Iteration 1000, Loss: 0.29324856400489807

# %%
# Loss from Lecture
Loss_from_lecture = 0.112526535987854

# Difference
0.29324856400489807 - Loss_from_lecture
# Out:
# 0.18072202801704407

# %% [markdown]
# Change your activation function from `torch.nn.Sigmoid()` to `torch.nn.Tanh`? Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# 50 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), # Input layer to Hidden layer
    torch.nn.Tanh(), # Activation function
    torch.nn.Linear(50, 1) # Hidden layer to Output layer
    )
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 0.9648199081420898
# Iteration 100, Loss: 0.6715439558029175
# Iteration 200, Loss: 0.4460100531578064
# Iteration 300, Loss: 0.31411778926849365
# Iteration 400, Loss: 0.252548485994339
# Iteration 500, Loss: 0.22447694838047028
# Iteration 600, Loss: 0.20356327295303345
# Iteration 700, Loss: 0.18537984788417816
# Iteration 800, Loss: 0.16950342059135437
# Iteration 900, Loss: 0.15547175705432892
# Iteration 1000, Loss: 0.14267875254154205

# %%
# Loss from Lecture
Loss_from_lecture = 0.112526535987854

# Difference
0.14267875254154205 - Loss_from_lecture
# Out:
# 0.03015221655368805

# %% [markdown]
# What is the difference between `torch.nn.Sigmoid()`, `torch.nn.ReLU` and `torch.nn.Tanh`?

# %%
# For the 1000th iteration of torch.nn.Sigmoid(), the loss is equal to: 0.2636105418205261
# For the 1000th iteration of torch.nn.ReLU(), the loss is equal to: 0.29324856400489807
# For the 1000th iteration of torch.nn.Tanh(), the loss is equal to: 0.14267875254154205

# Thus, the biggest loss occurs when using ReLU and the smallest loss occurs when using Tahn.

# %% [markdown]
# Return to `torch.nn.Sigmoid()`. Change your learning rate from `1e-3` to `1e-2` in your optimizer. Compare the loss functions from lecture to your modification on the **1000th** iteration.

# %%
# 50 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), # Input layer to Hidden layer
    torch.nn.Sigmoid(), # Activation function
    torch.nn.Linear(50, 1) # Hidden layer to Output layer
    )
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-2) # Using 2 instead of 3

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 0.995185136795044
# Iteration 100, Loss: 0.34335222840309143
# Iteration 200, Loss: 0.18170447647571564
# Iteration 300, Loss: 0.12342555075883865
# Iteration 400, Loss: 0.09625829756259918
# Iteration 500, Loss: 0.08138792216777802
# Iteration 600, Loss: 0.06738129258155823
# Iteration 700, Loss: 0.05224040150642395
# Iteration 800, Loss: 0.04129049926996231
# Iteration 900, Loss: 0.032846853137016296
# Iteration 1000, Loss: 0.027363844215869904

# %%
# Loss from Lecture
Loss_from_lecture = 0.112526535987854

# Difference
- 0.027363844215869904 + Loss_from_lecture
# Out:
# 0.0851626917719841

# %% [markdown]
# Modify your model to have **two hidden layers** instead of one. Give that code here.

# %%
# Two hidden layers
# 50 Neurons
model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), # Input layer to 1st hidden layer
    torch.nn.Sigmoid(), # Activation function after 1st hidden layer
    torch.nn.Linear(50, 30), # 1st hidden layer to 2nd hidden layer
    torch.nn.Sigmoid(), # Activation function after 2nd hidden layer
    torch.nn.Linear(30, 1) # 2nd hidden layer to output layer
    )
loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3) # Using 2 instead of 3

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 0.9998192191123962
# Iteration 100, Loss: 0.9160915613174438
# Iteration 200, Loss: 0.5754227042198181
# Iteration 300, Loss: 0.3941091299057007
# Iteration 400, Loss: 0.272714227437973
# Iteration 500, Loss: 0.19211135804653168
# Iteration 600, Loss: 0.16063444316387177
# Iteration 700, Loss: 0.14499276876449585
# Iteration 800, Loss: 0.13060027360916138
# Iteration 900, Loss: 0.12129007279872894
# Iteration 1000, Loss: 0.1132277101278305

# %%
# Loss from Lecture
Loss_from_lecture = 0.112526535987854

# Difference
0.1132277101278305 - Loss_from_lecture
# Out:
# 0.0007011741399765015

# %% [markdown]
# # 3) More Advanced
# Create a new file called `new_data.py`, make a new "hidden" function and add noise/ obscure the data (e.g. like what is done in `data.py` from lecture). Import that file here.

# %%
import new_data
import torch
import matplotlib.pyplot as plt

# %% [markdown]
# Define a new model and train it **poorly** in the cell below.

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(2, 50), # Input layer to Hidden layer
    torch.nn.Sigmoid(), # Activation function
    torch.nn.Linear(50, 1) # Hidden layer to Output layer
    )

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 100 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 1.2035441398620605
# Iteration 100, Loss: 0.9568573832511902
# Iteration 200, Loss: 0.9125540256500244
# Iteration 300, Loss: 0.8395512104034424
# Iteration 400, Loss: 0.7374554872512817
# Iteration 500, Loss: 0.6235063672065735
# Iteration 600, Loss: 0.5198290944099426
# Iteration 700, Loss: 0.44174957275390625
# Iteration 800, Loss: 0.3897808790206909
# Iteration 900, Loss: 0.3552888035774231
# Iteration 1000, Loss: 0.32806625962257385

# %% [markdown]
# Improve your model and train it **well** in the cell below. (You can add more neurons, iterations, etc).

# %% [markdown]
# Make foure subplots (two rows, two columns).
# - (TOP LEFT) Show what the "hidden pattern" is supposed to be.
# - (TOP RIGHT) Show that your "data" is.
# - (BOTTOM LEFT) Show your model's prediction when you trained it poorly.
# - (BOTTOM RIGHT) Show your model's prediction when you trained it well.

# %%
model = torch.nn.Sequential(
    torch.nn.Linear(2, 100), # Input layer to 1st hidden layer
    torch.nn.ReLU(), # Activation function after 1st hidden layer
    torch.nn.Linear(100, 50), # 1st hidden layer to 2nd hidden layer
    torch.nn.ReLU(), # Activation function after 2nd hidden layer
    torch.nn.Linear(50, 1) # 2nd hidden layer to output layer
    )

loss_fn = torch.nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

for t in range(1100): # 1000th Iteration
    y_pred = model(data.x)
    loss = loss_fn(y_pred, data.y)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if t % 50 == 0:
        print(f"Iteration {t}, Loss: {loss.item()}")
# Out:
# Iteration 0, Loss: 1.030078649520874
# Iteration 50, Loss: 0.5649914741516113
# Iteration 100, Loss: 0.31651753187179565
# Iteration 150, Loss: 0.22907990217208862
# Iteration 200, Loss: 0.1777762621641159
# Iteration 250, Loss: 0.13915038108825684
# Iteration 300, Loss: 0.10721421241760254
# Iteration 350, Loss: 0.0867215245962143
# Iteration 400, Loss: 0.07369361817836761
# Iteration 450, Loss: 0.06327486038208008
# Iteration 500, Loss: 0.05247753486037254
# Iteration 550, Loss: 0.04428752884268761
# Iteration 600, Loss: 0.03518937900662422
# Iteration 650, Loss: 0.029724670574069023
# Iteration 700, Loss: 0.025811029598116875
# Iteration 750, Loss: 0.022817296907305717
# Iteration 800, Loss: 0.020952295511960983
# Iteration 850, Loss: 0.02138436585664749
# Iteration 900, Loss: 0.01782042905688286
# Iteration 950, Loss: 0.01672886312007904
# Iteration 1000, Loss: 0.01574414223432541
# Iteration 1050, Loss: 0.015497925691306591

# %% [markdown]
# # 4) Challenge
# Find some data online and build a neural network around it. Make sure to also answer these questions:
# - Where did you find your data?
# - How well does your model match your data?

# %%
# I am really confused and honestly unsure how to approach this problem. 
# Planning on attending office hours to get help!

# %% [markdown]
# Once you are done, make sure to:
# - Download this notebook and all releveant files (`new_data.py`, stuff from question 4, etc) from datahub.
# - Move it to your **remote repository**.
# - Upload to Gradescope!
